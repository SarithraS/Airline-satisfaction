# %% [markdown]
# ## DATA PREPROCESSING AND DATA CLEANING

# %%
# Import the necessary libraries.
import pandas as pd
import numpy as np

# Avoid unnecessary warnings, (EX: software updates, version mismatch, and so on.)
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('airline.CSV')
df = df.drop(columns=['Unnamed: 0'])
df = df.drop(columns=['id'])
df = df.drop(columns=['Arrival_Delay_in_Minutes'])
df = df.drop(columns=['Flight_Distance'])
df = df.drop(columns=['Departure/Arrival time convenient'])
df = df.drop(columns=['Ease of Online booking'])
df = df.drop(columns=['Gate location'])

# %%
# Check the top5 values
df.head(10)
# Out:
#    Gender      Customer_Type  Age   Type_of_Travel     Class  \
# 0  Female     Loyal Customer   52  Business travel       Eco
# 1  Female     Loyal Customer   36  Business travel  Business
# 2    Male  disloyal Customer   20  Business travel       Eco
# 3    Male     Loyal Customer   44  Business travel  Business
# 4  Female     Loyal Customer   49  Business travel       Eco
# 5    Male     Loyal Customer   16  Business travel       Eco
# 6  Female     Loyal Customer   77  Business travel  Business
# 7  Female     Loyal Customer   43  Business travel  Business
# 8    Male     Loyal Customer   47  Business travel       Eco
# 9  Female     Loyal Customer   46  Business travel  Business
#
#    Inflight_wifi_service  Food_and_drink  Online_boarding  Seat_comfort  \
# 0                      5               3                4             3
# 1                      1               5                4             5
# 2                      2               2                2             2
# 3                      0               3                4             4
# 4                      2               4                1             2
# 5                      3               5                5             3
# 6                      5               3                5             5
# 7                      2               4                4             5
# 8                      5               5                5             5
# 9                      2               3                4             4
#
#    Inflight_entertainment  Onboard_service  Leg_room_service  \
# 0                       5                5                 5
# 1                       4                4                 4
# 2                       2                4                 1
# 3                       1                1                 1
# 4                       2                2                 2
# 5                       5                4                 3
# 6                       5                5                 5
# 7                       4                4                 4
# 8                       5                2                 2
# 9                       4                4                 4
#
#    Baggage_handling  Checkin_service  Inflight_service  Cleanliness  \
# 0                 5                2                 5            5
# 1                 4                3                 4            5
# 2                 3                2                 2            2
# 3                 1                3                 1            4
# 4                 2                4                 2            4
# 5                 1                1                 2            5
# 6                 5                4                 5            3
# 7                 4                5                 4            3
# 8                 5                3                 3            5
# 9                 4                5                 4            4
#
#    Departure_Delay_in_Minutes             satisfaction
# 0                          50                satisfied
# 1                           0                satisfied
# 2                           0  neutral or dissatisfied
# 3                           0                satisfied
# 4                           0                satisfied
# 5                           0                satisfied
# 6                           0                satisfied
# 7                          77                satisfied
# 8                           1                satisfied
# 9                          28                satisfied

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

var = ['Gender','Customer_Type','Type_of_Travel','Class','satisfaction']
  
for i in var:
    df[i] = le.fit_transform(df[i]).astype(int)

# %%
# Check the bottom five values.
df.tail()
# Out:
#        Gender  Customer_Type  Age  Type_of_Travel  Class  \
# 25971       1              1   34               0      0
# 25972       1              0   23               0      0
# 25973       0              0   17               1      1
# 25974       1              0   14               0      0
# 25975       0              0   42               1      1
#
#        Inflight_wifi_service  Food_and_drink  Online_boarding  Seat_comfort  \
# 25971                      3               4                3             4
# 25972                      4               4                4             4
# 25973                      2               2                1             2
# 25974                      3               4                4             4
# 25975                      2               4                2             2
#
#        Inflight_entertainment  Onboard_service  Leg_room_service  \
# 25971                       4                3                 2
# 25972                       4                4                 5
# 25973                       2                4                 3
# 25974                       4                3                 2
# 25975                       1                1                 2
#
#        Baggage_handling  Checkin_service  Inflight_service  Cleanliness  \
# 25971                 4                4                 5            4
# 25972                 5                5                 5            4
# 25973                 4                5                 4            2
# 25974                 5                4                 5            4
# 25975                 1                1                 1            1
#
#        Departure_Delay_in_Minutes  satisfaction
# 25971                           0             0
# 25972                           0             1
# 25973                           0             0
# 25974                           0             1
# 25975                           0             0

# %%
# Check the dimension of our datasets
df.shape
# Out:
# (25976, 18)

# %%
# Check the dataset size 
df.size
# Out:
# 467568

# %%
# Check the columns of dataset
df.columns
# Out:
# Index(['Gender', 'Customer_Type', 'Age', 'Type_of_Travel', 'Class',
#        'Inflight_wifi_service', 'Food_and_drink', 'Online_boarding',
#        'Seat_comfort', 'Inflight_entertainment', 'Onboard_service',
#        'Leg_room_service', 'Baggage_handling', 'Checkin_service',
#        'Inflight_service', 'Cleanliness', 'Departure_Delay_in_Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
# To know the information of our datsets
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25976 entries, 0 to 25975
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Gender                      25976 non-null  int32
#  1   Customer_Type               25976 non-null  int32
#  2   Age                         25976 non-null  int64
#  3   Type_of_Travel              25976 non-null  int32
#  4   Class                       25976 non-null  int32
#  5   Inflight_wifi_service       25976 non-null  int64
#  6   Food_and_drink              25976 non-null  int64
#  7   Online_boarding             25976 non-null  int64
#  8   Seat_comfort                25976 non-null  int64
#  9   Inflight_entertainment      25976 non-null  int64
#  10  Onboard_service             25976 non-null  int64
#  11  Leg_room_service            25976 non-null  int64
#  12  Baggage_handling            25976 non-null  int64
#  13  Checkin_service             25976 non-null  int64
#  14  Inflight_service            25976 non-null  int64
#  15  Cleanliness                 25976 non-null  int64
#  16  Departure_Delay_in_Minutes  25976 non-null  int64
#  17  satisfaction                25976 non-null  int32
# dtypes: int32(5), int64(13)
# memory usage: 3.1 MB

# %%
# Check the unique columns of our specific column
df['satisfaction'].unique()
# Out:
# array([1, 0])

# %%
# Check the value is null or notnull
df.isnull().head()
# Out:
#    Gender  Customer_Type    Age  Type_of_Travel  Class  Inflight_wifi_service  \
# 0   False          False  False           False  False                  False
# 1   False          False  False           False  False                  False
# 2   False          False  False           False  False                  False
# 3   False          False  False           False  False                  False
# 4   False          False  False           False  False                  False
#
#    Food_and_drink  Online_boarding  Seat_comfort  Inflight_entertainment  \
# 0           False            False         False                   False
# 1           False            False         False                   False
# 2           False            False         False                   False
# 3           False            False         False                   False
# 4           False            False         False                   False
#
#    Onboard_service  Leg_room_service  Baggage_handling  Checkin_service  \
# 0            False             False             False            False
# 1            False             False             False            False
# 2            False             False             False            False
# 3            False             False             False            False
# 4            False             False             False            False
#
#    Inflight_service  Cleanliness  Departure_Delay_in_Minutes  satisfaction
# 0             False        False                       False         False
# 1             False        False                       False         False
# 2             False        False                       False         False
# 3             False        False                       False         False
# 4             False        False                       False         False

# %%
# Remove the null value
df = df.dropna()

# %%
# Describe the datasets into stastical point of view
df.describe()
# Out:
#              Gender  Customer_Type           Age  Type_of_Travel  \
# count  25976.000000   25976.000000  25976.000000    25976.000000
# mean       0.492917       0.184747     39.620958        0.305590
# std        0.499959       0.388100     15.135685        0.460666
# min        0.000000       0.000000      7.000000        0.000000
# 25%        0.000000       0.000000     27.000000        0.000000
# 50%        0.000000       0.000000     40.000000        0.000000
# 75%        1.000000       0.000000     51.000000        1.000000
# max        1.000000       1.000000     85.000000        1.000000
#
#               Class  Inflight_wifi_service  Food_and_drink  Online_boarding  \
# count  25976.000000           25976.000000    25976.000000     25976.000000
# mean       0.592778               2.724746        3.215353         3.261665
# std        0.623703               1.335384        1.331506         1.355536
# min        0.000000               0.000000        0.000000         0.000000
# 25%        0.000000               2.000000        2.000000         2.000000
# 50%        1.000000               3.000000        3.000000         4.000000
# 75%        1.000000               4.000000        4.000000         4.000000
# max        2.000000               5.000000        5.000000         5.000000
#
#        Seat_comfort  Inflight_entertainment  Onboard_service  \
# count  25976.000000            25976.000000     25976.000000
# mean       3.449222                3.357753         3.385664
# std        1.320090                1.338299         1.282088
# min        1.000000                0.000000         0.000000
# 25%        2.000000                2.000000         2.000000
# 50%        4.000000                4.000000         4.000000
# 75%        5.000000                4.000000         4.000000
# max        5.000000                5.000000         5.000000
#
#        Leg_room_service  Baggage_handling  Checkin_service  Inflight_service  \
# count      25976.000000      25976.000000     25976.000000      25976.000000
# mean           3.350169          3.633238         3.314175          3.649253
# std            1.318862          1.176525         1.269332          1.180681
# min            0.000000          1.000000         1.000000          0.000000
# 25%            2.000000          3.000000         3.000000          3.000000
# 50%            4.000000          4.000000         3.000000          4.000000
# 75%            4.000000          5.000000         4.000000          5.000000
# max            5.000000          5.000000         5.000000          5.000000
#
#         Cleanliness  Departure_Delay_in_Minutes  satisfaction
# count  25976.000000                 25976.00000  25976.000000
# mean       3.286226                    14.30609      0.438982
# std        1.319330                    37.42316      0.496272
# min        0.000000                     0.00000      0.000000
# 25%        2.000000                     0.00000      0.000000
# 50%        3.000000                     0.00000      0.000000
# 75%        4.000000                    12.00000      1.000000
# max        5.000000                  1128.00000      1.000000

# %%
# Check the relation between each individual columns
df.corr().head()
# Out:
#                   Gender  Customer_Type       Age  Type_of_Travel     Class  \
# Gender          1.000000      -0.027878  0.009261        0.019930 -0.006411
# Customer_Type  -0.027878       1.000000 -0.294210       -0.307827  0.044415
# Age             0.009261      -0.294210  1.000000       -0.029773 -0.115125
# Type_of_Travel  0.019930      -0.307827 -0.029773        1.000000  0.485258
# Class          -0.006411       0.044415 -0.115125        0.485258  1.000000
#
#                 Inflight_wifi_service  Food_and_drink  Online_boarding  \
# Gender                      -0.006323       -0.014422        -0.056031
# Customer_Type                0.001333       -0.047269        -0.188418
# Age                          0.009242        0.023841         0.202058
# Type_of_Travel              -0.109021       -0.091164        -0.220843
# Class                       -0.032293       -0.095590        -0.299951
#
#                 Seat_comfort  Inflight_entertainment  Onboard_service  \
# Gender             -0.047765               -0.005217        -0.000423
# Customer_Type      -0.143362               -0.090418        -0.044628
# Age                 0.154507                0.068998         0.054977
# Type_of_Travel     -0.140981               -0.171904        -0.072902
# Class              -0.220988               -0.199558        -0.222258
#
#                 Leg_room_service  Baggage_handling  Checkin_service  \
# Gender                  0.028051          0.032202         0.000079
# Customer_Type          -0.042757          0.025470        -0.027565
# Age                     0.033299         -0.049863         0.025388
# Type_of_Travel         -0.142869         -0.039824         0.014292
# Class                  -0.204803         -0.176942        -0.158999
#
#                 Inflight_service  Cleanliness  Departure_Delay_in_Minutes  \
2725, 2859, 2927, 2946, 2961, 3107, 3283, 3292, 3447, 3526, 3602, 3708, 3837, 3893, 4050, 4135, 4202, 4356, 4462, 4519, 5310, 5326, 5639, 5752, 5831, 5972, 6095, 6144, 6335, 6446, 6469, 6583, 6592, 6857, 7097, 7420, 7607, 7608, 8055, 8089, 8183, 8229, 8244, 8255, 8384, 8438, 8535, 8538, 8601, 8670, 8725, 8843, 8921, 9070, 9164, 9241, 9672, 9730, 9761, 9778, 9852, 10285, 10380, 10383, 10423, 10453, 10514, 10542, 10565, 10568, 10639, 10843, 10889, 10922, 11092, 11228, 11250, 11259, 11261, 11381, 11410, 11677, 11698, 11722, ...], (1, 5): [186, 345, 2297, 2519, 2590, 2611, 2752, 2770, 3104, 3217, 3234, 3350, 3392, 3393, 4064, 4267, 4326, 4691, 4869, 4932, 5093, 5907, 6116, 6152, 6201, 6723, 6737, 6777, 6822, 6917, 7028, 7062, 7099, 7395, 7603, 7833, 7926, 8026, 8104, 8226, 9103, 9231, 9345, 9436, 9901, 10125, 10151, 10498, 11071, 11147, 11180, 11240, 11298, 11321, 11471, 11630, 11900, 12135, 12380, 12512, 12515, 12713, 12809, 12819, 13116, 14170, 14313, 15295, 15481, 15973, 16174, 16358, 16663, 16748, 16756, 16850, 16879, 16993, 17179, 17516, 17691, 18238, 18363, 18607, 19307, 19606, 19946, 20162, 20243, 20252, 20274, 20344, 20386, 20433, 20451, 20489, 20741, 20773, 20803, 21156, ...], (2, 1): [93, 145, 206, 208, 372, 472, 503, 649, 846, 981, 1098, 1147, 1375, 1655, 1679, 1702, 1739, 1958, 2294, 2304, 2398, 2424, 2526, 2545, 2636, 3021, 3049, 3054, 3132, 3223, 3444, 3689, 3714, 3793, 3835, 3883, 4142, 4243, 4325, 4687, 4714, 4750, 4855, 4899, 4976, 5059, 5128, 5366, 5473, 5517, 5572, 5637, 5662, 5991, 6023, 6070, 6099, 6101, 6110, 6178, 6347, 6413, 6508, 6635, 6657, 6674, 6854, 6950, 7002, 7054, 7324, 7412, 7591, 7753, 7816, 7846, 7880, 7962, 8064, 8088, 8093, 8194, 8254, 8481, 8588, 8801, 8883, 8923, 9161, 9254, 9358, 9405, 9422, 9432, 9668, 9687, 10048, 10511, 10702, 10855, ...], (2, 2): [2, 15, 16, 21, 24, 25, 26, 31, 38, 41, 44, 51, 53, 55, 66, 78, 101, 107, 108, 116, 124, 126, 133, 136, 139, 140, 153, 157, 168, 172, 184, 185, 187, 188, 195, 199, 219, 238, 244, 247, 260, 265, 278, 282, 286, 320, 325, 348, 352, 362, 36 ...

# %%
# Check the value counts for specific columns
df["satisfaction"].value_counts()
# Out:
# satisfaction
# 0    14573
# 1    11403
# Name: count, dtype: int64

# %%
# Check the specific column catagorical distribution
pd.Categorical(df["satisfaction"]).describe()
# Out:
#             counts     freqs
# categories
# 0            14573  0.561018
# 1            11403  0.438982

# %%
# Check if the value is duplicated or not
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25971    False
# 25972    False
# 25973    False
# 25974    False
# 25975    False
# Length: 25976, dtype: bool

# %%
# Calculate the total number of duplicated values
sum(df.duplicated())
# Out:
# 43

# %%
# Remove the duplicate values
df=df.drop_duplicates()

# %%
# Calculate the total number of duplicated values
sum(df.duplicated())
# Out:
# 0
