# %% [markdown]
# ## DATA VISUALIZATION AND DATA ANALYSIS

# %%
# Import the necessary libraries.
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('airline.CSV')
df = df.drop(columns=['Unnamed: 0'])
df = df.drop(columns=['id'])
df = df.drop(columns=['Arrival_Delay_in_Minutes'])
df = df.drop(columns=['Flight_Distance'])
df = df.drop(columns=['Departure/Arrival time convenient'])
df = df.drop(columns=['Ease of Online booking'])
df = df.drop(columns=['Gate location'])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

var = ['Gender','Customer_Type','Type_of_Travel','Class','satisfaction']
  
for i in var:
    df[i] = le.fit_transform(df[i]).astype(int)

# %%
# Check the top5 values
df.head()
# Out:
#    Gender  Customer_Type  Age  Type_of_Travel  Class  Inflight_wifi_service  \
# 0       0              0   52               0      1                      5
# 1       0              0   36               0      0                      1
# 2       1              1   20               0      1                      2
# 3       1              0   44               0      0                      0
# 4       0              0   49               0      1                      2
#
#    Food_and_drink  Online_boarding  Seat_comfort  Inflight_entertainment  \
# 0               3                4             3                       5
# 1               5                4             5                       4
# 2               2                2             2                       2
# 3               3                4             4                       1
# 4               4                1             2                       2
#
#    Onboard_service  Leg_room_service  Baggage_handling  Checkin_service  \
# 0                5                 5                 5                2
# 1                4                 4                 4                3
# 2                4                 1                 3                2
# 3                1                 1                 1                3
# 4                2                 2                 2                4
#
#    Inflight_service  Cleanliness  Departure_Delay_in_Minutes  satisfaction
# 0                 5            5                          50             1
# 1                 4            5                           0             1
# 2                 2            2                           0             0
# 3                 1            4                           0             1
# 4                 2            4                           0             1

# %%
# Remove the null value
df = df.dropna()

# %%
# Remove the duplicate values
df=df.drop_duplicates()

# %%
# Check the data is balanced or imbalanced so that's why we use Countplot.
plt.figure(figsize=(12,7))
sns.countplot(x='satisfaction',data=df)
# Out:
# <Axes: xlabel='satisfaction', ylabel='count'>

# %%
# Plot a Histogram
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.hist(df["Inflight wifi service"],color='red')

plt.subplot(1,2,2)
plt.hist(df["Food and drink"],color='blue')
# Out:
# (array([  25.,    0., 3214.,    0., 5387.,    0., 5484.,    0., 6186.,
#         5637.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
# Check how many columns are in datasets
df.columns
# Out:
# Index(['Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Inflight wifi service', 'Food and drink', 'Online boarding',
#        'Seat comfort', 'Inflight entertainment', 'On-board service',
#        'Leg room service', 'Baggage handling', 'Checkin service',
#        'Inflight service', 'Cleanliness', 'Departure Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
# Plot a Histogram.
df.hist(figsize=(15,55), color='green')
plt.show()

# %%
# Plot a Histogram
df["Class"].hist(figsize=(10,5),color='yellow',bins=25)
# Out:
# <Axes: >

# %%
# Check the outliers our datasets.
plt.boxplot(df["Online boarding"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fbb12013a0>,
#   <matplotlib.lines.Line2D at 0x1fbb1201640>],
#  'caps': [<matplotlib.lines.Line2D at 0x1fbb12018e0>,
#   <matplotlib.lines.Line2D at 0x1fbb1201b80>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1fbb1201100>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fbb1201e20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fbb120d100>],
#  'means': []}

# %%
# Plot a density plot
df["On-board service"].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
# Plot a distance plot
sns.displot(df["Baggage handling"], color='purple') 
# barplot, boxenplot, boxplot, countplot, displot, distplot, ecdfplot, histplot, kdeplot, pointplot, violinplot, stripplot

# %%
# Plot a distance plot.
sns.displot(df["Checkin service"], color='coral') # residplot, scatterplot

# %%
# Plot a head map for co relationships for each columns.
fig, ax = plt.subplots(figsize=(20,15))
sns.heatmap(df.corr(),annot = True, fmt='0.2%',cmap = 'autumn',ax=ax)
# Out:
# <Axes: >

# %%
# Plot a Piechart 
def plot(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(9,9), autopct='%1.2f%%', fontsize = 10)
    ax.set_title(variable + ' \n', fontsize = 10)
    return np.round(dataframe_pie/df.shape[0]*100,2)

plot(df, 'satisfaction')
# Out:
# satisfaction
# 0    56.17
# 1    43.83
# Name: count, dtype: float64
